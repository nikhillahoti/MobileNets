# %%
import tensorflow as tf
from keras.preprocessing import image
import numpy as np
import keras
from keras import Model
import time
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import Conv3D

fileName = "Trump.jpg"



# Global MobileNets model
mobile = keras.applications.mobilenet.MobileNet(weights="imagenet")
model = Model(mobile.input, mobile.layers[52].output)
# Out:
# /home/nikhil/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
for layer in model.layers:
    print(layer)
    
layer50 = model.layers[50]
W = np.array(layer50.get_weights())

print("\n\n Weight Size")
print(W.shape)
# Out:
# ...
#
#
#  Weight Size
# (1, 3, 3, 512, 1)

# %%
def write_to_file_weights_layer_Sixteen(fileName, W):
    fTemp = open(fileName, "w")
    for i in range(512):
        for j in range(3):
            for k in range(3):
                for l in range(1):
                    fTemp.write(str(W[j][k][i][l]) + "\n")
    fTemp.close()

# %%
for layer in model.layers:
    print(layer)
    
layer50 = model.layers[50]
W = np.array(layer50.get_weights())
print(W.shape)

W = layer50.get_weights()[0]
write_to_file_weights_layer_Sixteen("data/SixteenthLayer/weightsNorm.txt", W)

W[:,:,:,:] = 1
write_to_file_weights_layer_Sixteen("data/SixteenthLayer/weightsSet1.txt", W)
# Out:
# ...
# (1, 3, 3, 512, 1)

# %%
import math as m
layer51 = model.layers[51]
W = np.array(layer51.get_weights())
print(W.shape)

batchNorm = model.layers[51].get_weights()

fMean = open("data/SixteenthLayer/Sixteenth_Layer_Mean.txt", "w")
fSD = open("data/SixteenthLayer/Sixteenth_Layer_StanDev.txt", "w")
fGamma = open("data/SixteenthLayer/Sixteenth_Layer_Gamma.txt", "w")
fBeta = open("data/SixteenthLayer/Sixteenth_Layer_Beta.txt", "w")


for i in range(len(batchNorm[0])):
    fGamma.write(str(float(batchNorm[0][i])) + "\n")

for i in range(len(batchNorm[1])):
    fBeta.write(str(float(batchNorm[1][i])) + "\n")

for i in range(len(batchNorm[2])):
    fMean.write(str(float(batchNorm[2][i])) + "\n")

for i in range(len(batchNorm[3])):
    # The Value for Epsilon is assumed to be 0.001 in this implementation
    fSD.write(str(m.sqrt(float(batchNorm[3][i]) + 0.001)) + "\n")


print(batchNorm[0])
print(batchNorm[1])
print(batchNorm[2])
print(batchNorm[3])

fMean.close()
fSD.close()
fGamma.close()
fBeta.close()
# Out:
# (4, 512)
# [1.1041038  0.76828915 0.80795616 1.8531246  0.74270326 2.8236017
#  1.2594748  1.1315802  1.5321481  0.9935821  1.0891867  1.1781125
#  0.9397525  0.8349669  1.0779442  1.2029991  0.92906344 0.92774594
#  0.58305216 0.93313396 0.6993719  1.0737834  0.9520599  1.2689621
#  1.2534412  0.68095666 1.0289601  1.1389283  0.7207199  0.92443526
#  1.229256   1.4150676  0.67098856 0.73200953 1.0421213  1.285244
#  0.8399127  0.675927   0.75769943 2.4620652  0.63535905 0.98824865
#  1.1368709  1.628394   0.7502748  0.70561385 0.88287234 0.6849756
#  1.16082    1.7165773  1.876751   1.6596259  0.78582424 0.9897022
#  1.2164099  0.6660497  1.2458231  0.6984106  0.73776823 1.380839
#  0.8184789  0.8326327  2.1220613  1.2493498  0.8010142  0.76215464
#  1.5899768  1.3968791  0.63882816 0.8111457  1.5544226  1.4663271
#  0.75587505 1.5046952  1.1657437  1.2966954  1.3130561  1.2743613
#  0.73261523 0.53339463 0.668433   0.819353   0.8875362  0.6723707
# ...

# %%
def checkFile_SixteenthLayer():
    fExp = open('data/SixteenthLayer/Sixteenth_Layer_Output.txt', 'r')
    fAct = open('data/SixteenthLayer/output.txt', 'r')
    
    cExp = fExp.readlines()
    cAct = fAct.readlines()
    counter = 0
    for i in range(len(cExp)):
         if int(round(float(cAct[i].strip()))) != int(round(float(cExp[i].strip()))):
            counter += 1
            if(counter < 30):
                print(str(cAct[i].strip()) + "--->" + str(cExp[i].strip()))
            
        
    print("Number of mismatch - " + str(counter))
    
    fExp.close()
    fAct.close()

# %%
checkFile_SixteenthLayer()
# Out:
# 0.500305--->0.49972707
# 1.499687--->1.5000092
# 2.500147--->2.4998193
# 0.500135--->0.49997324
# 2.499873--->2.5000627
# 1.500081--->1.4998996
# 1.500009--->1.499919
# Number of mismatch - 7
