# %%
import tensorflow as tf
from keras.preprocessing import image
import numpy as np
import keras
from keras import Model
import time
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import Conv3D

fileName = "Trump.jpg"



# Global MobileNets model
mobile = keras.applications.mobilenet.MobileNet(weights="imagenet")
model = Model(mobile.input, mobile.layers[64].output)
# Out:
# /home/nikhil/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
for layer in model.layers:
    print(layer)
    
layer62 = model.layers[62]
W = np.array(layer62.get_weights())

print("\n\n Weight Size")
print(W.shape)
# Out:
# ...
#
#
#  Weight Size
# (1, 3, 3, 512, 1)

# %%
def write_to_file_weights_layer_Twenty(fileName, W):
    fTemp = open(fileName, "w")
    for i in range(512):
        for j in range(3):
            for k in range(3):
                for l in range(1):
                    fTemp.write(str(W[j][k][i][l]) + "\n")
    fTemp.close()

# %%
for layer in model.layers:
    print(layer)
    
layer62 = model.layers[62]
W = np.array(layer62.get_weights())
print(W.shape)

W = layer62.get_weights()[0]
write_to_file_weights_layer_Twenty("data/TwentyLayer/weightsNorm.txt", W)

W[:,:,:,:] = 1
write_to_file_weights_layer_Twenty("data/TwentyLayer/weightsSet1.txt", W)
# Out:
# ...
# (1, 3, 3, 512, 1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-32294505136a> in <module>()
#       7
#       8 W = layer62.get_weights()[0]
# ----> 9 write_to_file_weights_layer_Twenty("data/TwentyLayer/weightsNorm.txt", W)
#      10
#      11 W[:,:,:,:] = 1
#
# NameError: name 'write_to_file_weights_layer_Twenty' is not defined

# %%
import math as m
layer57 = model.layers[57]
W = np.array(layer57.get_weights())
print(W.shape)

batchNorm = model.layers[57].get_weights()

fMean = open("data/EighteenthLayer/Eighteenth_Layer_Mean.txt", "w")
fSD = open("data/EighteenthLayer/Eighteenth_Layer_StanDev.txt", "w")
fGamma = open("data/EighteenthLayer/Eighteenth_Layer_Gamma.txt", "w")
fBeta = open("data/EighteenthLayer/Eighteenth_Layer_Beta.txt", "w")


for i in range(len(batchNorm[0])):
    fGamma.write(str(float(batchNorm[0][i])) + "\n")

for i in range(len(batchNorm[1])):
    fBeta.write(str(float(batchNorm[1][i])) + "\n")

for i in range(len(batchNorm[2])):
    fMean.write(str(float(batchNorm[2][i])) + "\n")

for i in range(len(batchNorm[3])):
    # The Value for Epsilon is assumed to be 0.001 in this implementation
    fSD.write(str(m.sqrt(float(batchNorm[3][i]) + 0.001)) + "\n")


print(batchNorm[0])
print(batchNorm[1])
print(batchNorm[2])
print(batchNorm[3])

fMean.close()
fSD.close()
fGamma.close()
fBeta.close()
# Out:
# (4, 512)
# [2.1370268  1.1299222  0.5857306  1.1435423  0.87766314 0.8723635
#  1.0882258  0.73348683 0.9128122  1.0304592  1.5480984  1.0117456
#  0.701367   0.58724713 0.61758184 1.0651499  0.42044556 0.80127496
#  0.87237835 1.5288575  1.8011718  0.77978146 0.67446864 0.7406469
#  0.8135366  1.487878   0.80840266 0.50168186 0.69846696 1.3439397
#  0.84863204 0.6691651  1.0743922  0.6864439  1.0742319  0.59534025
#  0.5114014  1.7022393  0.8278801  0.5966861  1.2427859  2.1660962
#  0.80393845 0.5606985  0.95657885 0.843527   1.3495259  0.7426843
#  1.1638224  0.9404034  0.96272475 1.22807    1.6115961  0.592682
#  0.8736457  1.2386273  0.6927556  0.9464044  1.5464773  1.3252913
#  1.5014979  0.6623976  1.6356177  0.7568381  0.69478023 0.9046736
#  1.5715258  1.0595572  0.9484629  0.7001362  1.0322657  0.78269714
#  0.8797878  0.9143978  0.738906   0.85663307 1.046412   0.8826017
#  2.2298758  0.7582434  0.9855083  0.7325799  0.87986255 0.74064547
# ...

# %%
def checkFile_EighteenthLayer():
    fExp = open('data/EighteenthLayer/Eighteenth_Layer_Output.txt', 'r')
    fAct = open('data/EighteenthLayer/output.txt', 'r')
    
    cExp = fExp.readlines()
    cAct = fAct.readlines()
    counter = 0
    for i in range(len(cExp)):
         if int(round(float(cAct[i].strip()))) != int(round(float(cExp[i].strip()))):
            counter += 1
            if(counter < 30):
                print(str(cAct[i].strip()) + "--->" + str(cExp[i].strip()))
            
        
    print("Number of mismatch - " + str(counter))
    
    fExp.close()
    fAct.close()

# %%
checkFile_EighteenthLayer()
# Out:
# 3.499897--->3.5001585
# 0.499868--->0.50018823
# 1.500153--->1.4998223
# 0.500009--->0.49978465
# 0.499957--->0.5000879
# 3.500012--->3.4999917
# 1.499848--->1.5002476
# 0.499639--->0.50044566
# 2.500001--->2.4999695
# 2.500294--->2.4993072
# 1.499936--->1.5003555
# 2.500068--->2.4996407
# Number of mismatch - 12
